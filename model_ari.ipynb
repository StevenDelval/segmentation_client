# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
pd.options.display.max_rows = 150
pd.options.display.max_columns = 150

# %%
df = pd.read_csv("data/data_merge.csv")



df['new_date'] =df["recence"].apply(lambda x: pd.to_datetime('22/10/2018',dayfirst=True) - pd.Timedelta(days=x))

# %%
df_debut = df.loc[df["new_date"] <= pd.to_datetime('1/03/2018',dayfirst=True)]
df_debut_2mois = df.loc[(df["new_date"] <= pd.to_datetime('1/05/2018',dayfirst=True)) & (df["new_date"] > pd.to_datetime('1/03/2018',dayfirst=True))]
df_debut_4mois = df.loc[(df["new_date"] <= pd.to_datetime('1/07/2018',dayfirst=True)) & (df["new_date"] > pd.to_datetime('1/03/2018',dayfirst=True))]
df_debut_6mois = df.loc[(df["new_date"] <= pd.to_datetime('1/09/2018',dayfirst=True)) & (df["new_date"] > pd.to_datetime('1/03/2018',dayfirst=True))]
df_debut_8mois = df.loc[(df["new_date"] <= pd.to_datetime('1/11/2018',dayfirst=True)) & (df["new_date"] > pd.to_datetime('1/03/2018',dayfirst=True))]


for dataframe in [df,df_debut,df_debut_2mois,df_debut_4mois,df_debut_6mois,df_debut_8mois]:
    dataframe.drop("new_date",axis=1,inplace=True)
# Out:
# /tmp/ipykernel_28774/2362626596.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.drop("new_date",axis=1,inplace=True)
# /tmp/ipykernel_28774/2362626596.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.drop("new_date",axis=1,inplace=True)
# /tmp/ipykernel_28774/2362626596.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.drop("new_date",axis=1,inplace=True)
# /tmp/ipykernel_28774/2362626596.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.drop("new_date",axis=1,inplace=True)
# /tmp/ipykernel_28774/2362626596.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.drop("new_date",axis=1,inplace=True)

# %%
num_columns = [col for col in df.columns if df[col].dtype != "object"]
cat_columns = [col for col in df.columns if df[col].dtype == "object"]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import  StandardScaler,OneHotEncoder,FunctionTransformer
from sklearn.decomposition import PCA,TruncatedSVD
from sklearn.pipeline import Pipeline
from sklearn.manifold import TSNE

std = StandardScaler()
ohe= OneHotEncoder(sparse_output=False)

log_1p = FunctionTransformer(func=np.log1p)
preprocessor_pca = ColumnTransformer(
    transformers=[
        ("ohe",ohe,cat_columns),
        ("log",log_1p,num_columns)
    ]
    
)
tsne=Pipeline([
     ('preprocessor', preprocessor_pca),
     ('std', std ),
     ("tsne", TSNE(n_components=3,random_state=42,verbose=2,n_jobs=-1))
])

tsne_value_debut = tsne.fit_transform(df_debut)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 55215 samples in 0.001s...
# [t-SNE] Computed neighbors for 55215 samples in 5.504s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 55215
# [t-SNE] Computed conditional probabilities for sample 2000 / 55215
# [t-SNE] Computed conditional probabilities for sample 3000 / 55215
# [t-SNE] Computed conditional probabilities for sample 4000 / 55215
# [t-SNE] Computed conditional probabilities for sample 5000 / 55215
# [t-SNE] Computed conditional probabilities for sample 6000 / 55215
# [t-SNE] Computed conditional probabilities for sample 7000 / 55215
# [t-SNE] Computed conditional probabilities for sample 8000 / 55215
# [t-SNE] Computed conditional probabilities for sample 9000 / 55215
# [t-SNE] Computed conditional probabilities for sample 10000 / 55215
# [t-SNE] Computed conditional probabilities for sample 11000 / 55215
# [t-SNE] Computed conditional probabilities for sample 12000 / 55215
# [t-SNE] Computed conditional probabilities for sample 13000 / 55215
# [t-SNE] Computed conditional probabilities for sample 14000 / 55215
# [t-SNE] Computed conditional probabilities for sample 15000 / 55215
# [t-SNE] Computed conditional probabilities for sample 16000 / 55215
# [t-SNE] Computed conditional probabilities for sample 17000 / 55215
# [t-SNE] Computed conditional probabilities for sample 18000 / 55215
# [t-SNE] Computed conditional probabilities for sample 19000 / 55215
# [t-SNE] Computed conditional probabilities for sample 20000 / 55215
# [t-SNE] Computed conditional probabilities for sample 21000 / 55215
# [t-SNE] Computed conditional probabilities for sample 22000 / 55215
# [t-SNE] Computed conditional probabilities for sample 23000 / 55215
# [t-SNE] Computed conditional probabilities for sample 24000 / 55215
# [t-SNE] Computed conditional probabilities for sample 25000 / 55215
# [t-SNE] Computed conditional probabilities for sample 26000 / 55215
# [t-SNE] Computed conditional probabilities for sample 27000 / 55215
# [t-SNE] Computed conditional probabilities for sample 28000 / 55215
# [t-SNE] Computed conditional probabilities for sample 29000 / 55215
# [t-SNE] Computed conditional probabilities for sample 30000 / 55215
# [t-SNE] Computed conditional probabilities for sample 31000 / 55215
# [t-SNE] Computed conditional probabilities for sample 32000 / 55215
# [t-SNE] Computed conditional probabilities for sample 33000 / 55215
# [t-SNE] Computed conditional probabilities for sample 34000 / 55215
# [t-SNE] Computed conditional probabilities for sample 35000 / 55215
# [t-SNE] Computed conditional probabilities for sample 36000 / 55215
# [t-SNE] Computed conditional probabilities for sample 37000 / 55215
# [t-SNE] Computed conditional probabilities for sample 38000 / 55215
# [t-SNE] Computed conditional probabilities for sample 39000 / 55215
# [t-SNE] Computed conditional probabilities for sample 40000 / 55215
# [t-SNE] Computed conditional probabilities for sample 41000 / 55215
# [t-SNE] Computed conditional probabilities for sample 42000 / 55215
# [t-SNE] Computed conditional probabilities for sample 43000 / 55215
# [t-SNE] Computed conditional probabilities for sample 44000 / 55215
# [t-SNE] Computed conditional probabilities for sample 45000 / 55215
# [t-SNE] Computed conditional probabilities for sample 46000 / 55215
# [t-SNE] Computed conditional probabilities for sample 47000 / 55215
# [t-SNE] Computed conditional probabilities for sample 48000 / 55215
# [t-SNE] Computed conditional probabilities for sample 49000 / 55215
# [t-SNE] Computed conditional probabilities for sample 50000 / 55215
# [t-SNE] Computed conditional probabilities for sample 51000 / 55215
# [t-SNE] Computed conditional probabilities for sample 52000 / 55215
# [t-SNE] Computed conditional probabilities for sample 53000 / 55215
# [t-SNE] Computed conditional probabilities for sample 54000 / 55215
# [t-SNE] Computed conditional probabilities for sample 55000 / 55215
# [t-SNE] Computed conditional probabilities for sample 55215 / 55215
# [t-SNE] Mean sigma: 0.709707
# [t-SNE] Computed conditional probabilities in 1.639s
# [t-SNE] Iteration 50: error = 100.5011292, gradient norm = 0.0108114 (50 iterations in 43.414s)
# [t-SNE] Iteration 100: error = 88.9577179, gradient norm = 0.0032343 (50 iterations in 31.358s)
# [t-SNE] Iteration 150: error = 85.8220901, gradient norm = 0.0019038 (50 iterations in 25.392s)
# [t-SNE] Iteration 200: error = 84.2491608, gradient norm = 0.0013526 (50 iterations in 26.574s)
# [t-SNE] Iteration 250: error = 83.2812653, gradient norm = 0.0010638 (50 iterations in 27.060s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 83.281265
# [t-SNE] Iteration 300: error = 3.4134417, gradient norm = 0.0028442 (50 iterations in 23.616s)
# [t-SNE] Iteration 350: error = 2.7591214, gradient norm = 0.0026776 (50 iterations in 30.123s)
# [t-SNE] Iteration 400: error = 2.3681846, gradient norm = 0.0022905 (50 iterations in 30.301s)
# [t-SNE] Iteration 450: error = 2.1279156, gradient norm = 0.0019683 (50 iterations in 26.676s)
# [t-SNE] Iteration 500: error = 1.9664664, gradient norm = 0.0017273 (50 iterations in 37.807s)
# [t-SNE] Iteration 550: error = 1.8505572, gradient norm = 0.0015480 (50 iterations in 34.308s)
# [t-SNE] Iteration 600: error = 1.7634050, gradient norm = 0.0013947 (50 iterations in 38.694s)
# [t-SNE] Iteration 650: error = 1.6964587, gradient norm = 0.0012598 (50 iterations in 37.543s)
# [t-SNE] Iteration 700: error = 1.6449944, gradient norm = 0.0010975 (50 iterations in 33.224s)
# [t-SNE] Iteration 750: error = 1.6070147, gradient norm = 0.0008758 (50 iterations in 37.360s)
# [t-SNE] Iteration 800: error = 1.5800891, gradient norm = 0.0007177 (50 iterations in 40.823s)
# [t-SNE] Iteration 850: error = 1.5608971, gradient norm = 0.0005605 (50 iterations in 31.361s)
# [t-SNE] Iteration 900: error = 1.5461941, gradient norm = 0.0004865 (50 iterations in 34.224s)
# [t-SNE] Iteration 950: error = 1.5344542, gradient norm = 0.0003822 (50 iterations in 35.471s)
# [t-SNE] Iteration 1000: error = 1.5258007, gradient norm = 0.0003139 (50 iterations in 31.671s)
# [t-SNE] KL divergence after 1000 iterations: 1.525801

# %%
# import pickle
# # pickle_out = open("tsne.pkl", "wb") 
# # pickle.dump(tsne_value, pickle_out) 
# # pickle_out.close()
# pickle_in = open('tsne.pkl', 'rb') 
# tsne_value = pickle.load(pickle_in)

# %%
from yellowbrick.cluster import KElbowVisualizer
visualizer = KElbowVisualizer(KMeans(n_init=10,random_state=42),metric="distortion", k=(2,12),timings=False)

visualizer.fit(tsne_value_debut)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
# Out:
# <AxesSubplot: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
kmeans = KMeans(n_clusters=5,n_init=10,random_state=42)
kmeans.fit(tsne_value_debut)
# Out:
# KMeans(n_clusters=5, n_init=10, random_state=42)

# %%
df_debut["label"]=kmeans.labels_
# Out:
# /tmp/ipykernel_28774/1551135478.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_debut["label"]=kmeans.labels_

# %%
# %matplotlib inline
import matplotlib.colors as mcolors
from mpl_toolkits.mplot3d import Axes3D

# Create figure and axes
fig = plt.figure()
fig.set_size_inches(25, 15)
ax = []
for i in range(8):
    if i<4:
        ax.append(fig.add_subplot(1, 4, i+1, projection='3d'))
    else:
        ax.append(fig.add_subplot(2, 4, i+1, projection='3d'))

# Create a list of colors from the Matplotlib "Set1" palette
set1_colors = list(mcolors.TABLEAU_COLORS.values())[:10]

# Create a dictionary to map colors to values from the list
color_dict = {i: set1_colors[i] for i in range(len(set1_colors))}


# Plot the 3D scatter plot from different angles

for i in range(8):
    ax[i].scatter3D(tsne_value_debut[:,0],tsne_value_debut[:,1],tsne_value_debut[:,2],marker=".",c=[color_dict[i] for i in df_debut["label"]])
    ax[i].view_init(elev=i*20-60., azim=i*40)
plt.show()

# %%
from sklearn.metrics import adjusted_rand_score

ari_scores = []
nb_mois = 0

kmeans = KMeans(n_clusters=5,n_init=10,random_state=42)
y_pred = kmeans.fit_predict(tsne_value_debut)
ari = adjusted_rand_score(df_debut["label"], y_pred[0:len(df_debut)])
ari_scores.append(ari)

for dataframe in [df_debut_2mois,df_debut_4mois,df_debut_6mois,df_debut_8mois]:
    kmeans = KMeans(n_clusters=5,n_init=10,random_state=42)
    y_pred = kmeans.fit_predict(tsne.fit_transform(pd.concat([df_debut, dataframe], ignore_index=True)))
    ari = adjusted_rand_score(df_debut["label"], y_pred[0:len(df_debut)])
    ari_scores.append(ari)

# Afficher le graphique de l'ARI
plt.plot([0,2,4,6,8], ari_scores, '-o')
plt.xlabel('Nombre de mois')
plt.ylabel('ARI')
plt.title('Performance de K-means en fonction du temps en mois')
plt.show()
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 68449 samples in 0.002s...
# [t-SNE] Computed neighbors for 68449 samples in 6.722s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 68449
# [t-SNE] Computed conditional probabilities for sample 2000 / 68449
# [t-SNE] Computed conditional probabilities for sample 3000 / 68449
# [t-SNE] Computed conditional probabilities for sample 4000 / 68449
# [t-SNE] Computed conditional probabilities for sample 5000 / 68449
# [t-SNE] Computed conditional probabilities for sample 6000 / 68449
# [t-SNE] Computed conditional probabilities for sample 7000 / 68449
# [t-SNE] Computed conditional probabilities for sample 8000 / 68449
# [t-SNE] Computed conditional probabilities for sample 9000 / 68449
# [t-SNE] Computed conditional probabilities for sample 10000 / 68449
# [t-SNE] Computed conditional probabilities for sample 11000 / 68449
# [t-SNE] Computed conditional probabilities for sample 12000 / 68449
# [t-SNE] Computed conditional probabilities for sample 13000 / 68449
# [t-SNE] Computed conditional probabilities for sample 14000 / 68449
# [t-SNE] Computed conditional probabilities for sample 15000 / 68449
# [t-SNE] Computed conditional probabilities for sample 16000 / 68449
# [t-SNE] Computed conditional probabilities for sample 17000 / 68449
# [t-SNE] Computed conditional probabilities for sample 18000 / 68449
# [t-SNE] Computed conditional probabilities for sample 19000 / 68449
# [t-SNE] Computed conditional probabilities for sample 20000 / 68449
# [t-SNE] Computed conditional probabilities for sample 21000 / 68449
# [t-SNE] Computed conditional probabilities for sample 22000 / 68449
# [t-SNE] Computed conditional probabilities for sample 23000 / 68449
# [t-SNE] Computed conditional probabilities for sample 24000 / 68449
# [t-SNE] Computed conditional probabilities for sample 25000 / 68449
# [t-SNE] Computed conditional probabilities for sample 26000 / 68449
# [t-SNE] Computed conditional probabilities for sample 27000 / 68449
# [t-SNE] Computed conditional probabilities for sample 28000 / 68449
# [t-SNE] Computed conditional probabilities for sample 29000 / 68449
# [t-SNE] Computed conditional probabilities for sample 30000 / 68449
# [t-SNE] Computed conditional probabilities for sample 31000 / 68449
# [t-SNE] Computed conditional probabilities for sample 32000 / 68449
# [t-SNE] Computed conditional probabilities for sample 33000 / 68449
# [t-SNE] Computed conditional probabilities for sample 34000 / 68449
# [t-SNE] Computed conditional probabilities for sample 35000 / 68449
# [t-SNE] Computed conditional probabilities for sample 36000 / 68449
# [t-SNE] Computed conditional probabilities for sample 37000 / 68449
# [t-SNE] Computed conditional probabilities for sample 38000 / 68449
# [t-SNE] Computed conditional probabilities for sample 39000 / 68449
# [t-SNE] Computed conditional probabilities for sample 40000 / 68449
# [t-SNE] Computed conditional probabilities for sample 41000 / 68449
# [t-SNE] Computed conditional probabilities for sample 42000 / 68449
# [t-SNE] Computed conditional probabilities for sample 43000 / 68449
# [t-SNE] Computed conditional probabilities for sample 44000 / 68449
# [t-SNE] Computed conditional probabilities for sample 45000 / 68449
# [t-SNE] Computed conditional probabilities for sample 46000 / 68449
# [t-SNE] Computed conditional probabilities for sample 47000 / 68449
# [t-SNE] Computed conditional probabilities for sample 48000 / 68449
# [t-SNE] Computed conditional probabilities for sample 49000 / 68449
# [t-SNE] Computed conditional probabilities for sample 50000 / 68449
# [t-SNE] Computed conditional probabilities for sample 51000 / 68449
# [t-SNE] Computed conditional probabilities for sample 52000 / 68449
# [t-SNE] Computed conditional probabilities for sample 53000 / 68449
# [t-SNE] Computed conditional probabilities for sample 54000 / 68449
# [t-SNE] Computed conditional probabilities for sample 55000 / 68449
# [t-SNE] Computed conditional probabilities for sample 56000 / 68449
# [t-SNE] Computed conditional probabilities for sample 57000 / 68449
# [t-SNE] Computed conditional probabilities for sample 58000 / 68449
# [t-SNE] Computed conditional probabilities for sample 59000 / 68449
# [t-SNE] Computed conditional probabilities for sample 60000 / 68449
# [t-SNE] Computed conditional probabilities for sample 61000 / 68449
# [t-SNE] Computed conditional probabilities for sample 62000 / 68449
# [t-SNE] Computed conditional probabilities for sample 63000 / 68449
# [t-SNE] Computed conditional probabilities for sample 64000 / 68449
# [t-SNE] Computed conditional probabilities for sample 65000 / 68449
# [t-SNE] Computed conditional probabilities for sample 66000 / 68449
# [t-SNE] Computed conditional probabilities for sample 67000 / 68449
# [t-SNE] Computed conditional probabilities for sample 68000 / 68449
# [t-SNE] Computed conditional probabilities for sample 68449 / 68449
# [t-SNE] Mean sigma: 0.687359
# [t-SNE] Computed conditional probabilities in 1.947s
# [t-SNE] Iteration 50: error = 102.7447510, gradient norm = 0.0097408 (50 iterations in 60.793s)
# [t-SNE] Iteration 100: error = 90.8777924, gradient norm = 0.0029593 (50 iterations in 36.895s)
# [t-SNE] Iteration 150: error = 87.5615005, gradient norm = 0.0017605 (50 iterations in 33.436s)
# [t-SNE] Iteration 200: error = 85.8766098, gradient norm = 0.0012625 (50 iterations in 33.839s)
# [t-SNE] Iteration 250: error = 84.8208389, gradient norm = 0.0009810 (50 iterations in 30.065s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 84.820839
# [t-SNE] Iteration 300: error = 3.5616450, gradient norm = 0.0026218 (50 iterations in 32.937s)
# [t-SNE] Iteration 350: error = 2.8842318, gradient norm = 0.0024709 (50 iterations in 35.275s)
# [t-SNE] Iteration 400: error = 2.4793842, gradient norm = 0.0021227 (50 iterations in 35.348s)
# [t-SNE] Iteration 450: error = 2.2274845, gradient norm = 0.0018358 (50 iterations in 35.909s)
# [t-SNE] Iteration 500: error = 2.0568159, gradient norm = 0.0016123 (50 iterations in 35.934s)
# [t-SNE] Iteration 550: error = 1.9336112, gradient norm = 0.0014451 (50 iterations in 37.775s)
# [t-SNE] Iteration 600: error = 1.8408892, gradient norm = 0.0013053 (50 iterations in 37.105s)
# [t-SNE] Iteration 650: error = 1.7695739, gradient norm = 0.0011707 (50 iterations in 43.851s)
# [t-SNE] Iteration 700: error = 1.7144158, gradient norm = 0.0010236 (50 iterations in 42.689s)
# [t-SNE] Iteration 750: error = 1.6716928, gradient norm = 0.0008957 (50 iterations in 34.974s)
# [t-SNE] Iteration 800: error = 1.6390002, gradient norm = 0.0007909 (50 iterations in 37.659s)
# [t-SNE] Iteration 850: error = 1.6144931, gradient norm = 0.0006106 (50 iterations in 39.692s)
# [t-SNE] Iteration 900: error = 1.5965163, gradient norm = 0.0004733 (50 iterations in 39.564s)
# [t-SNE] Iteration 950: error = 1.5836935, gradient norm = 0.0003912 (50 iterations in 41.623s)
# [t-SNE] Iteration 1000: error = 1.5730879, gradient norm = 0.0003506 (50 iterations in 45.596s)
# [t-SNE] KL divergence after 1000 iterations: 1.573088
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 80807 samples in 0.003s...
# [t-SNE] Computed neighbors for 80807 samples in 10.316s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 80807
# [t-SNE] Computed conditional probabilities for sample 2000 / 80807
# [t-SNE] Computed conditional probabilities for sample 3000 / 80807
# [t-SNE] Computed conditional probabilities for sample 4000 / 80807
# [t-SNE] Computed conditional probabilities for sample 5000 / 80807
# [t-SNE] Computed conditional probabilities for sample 6000 / 80807
# [t-SNE] Computed conditional probabilities for sample 7000 / 80807
# [t-SNE] Computed conditional probabilities for sample 8000 / 80807
# [t-SNE] Computed conditional probabilities for sample 9000 / 80807
# [t-SNE] Computed conditional probabilities for sample 10000 / 80807
# [t-SNE] Computed conditional probabilities for sample 11000 / 80807
# [t-SNE] Computed conditional probabilities for sample 12000 / 80807
# [t-SNE] Computed conditional probabilities for sample 13000 / 80807
# [t-SNE] Computed conditional probabilities for sample 14000 / 80807
# [t-SNE] Computed conditional probabilities for sample 15000 / 80807
# [t-SNE] Computed conditional probabilities for sample 16000 / 80807
# [t-SNE] Computed conditional probabilities for sample 17000 / 80807
# [t-SNE] Computed conditional probabilities for sample 18000 / 80807
# [t-SNE] Computed conditional probabilities for sample 19000 / 80807
# [t-SNE] Computed conditional probabilities for sample 20000 / 80807
# [t-SNE] Computed conditional probabilities for sample 21000 / 80807
# [t-SNE] Computed conditional probabilities for sample 22000 / 80807
# [t-SNE] Computed conditional probabilities for sample 23000 / 80807
# [t-SNE] Computed conditional probabilities for sample 24000 / 80807
# [t-SNE] Computed conditional probabilities for sample 25000 / 80807
# [t-SNE] Computed conditional probabilities for sample 26000 / 80807
# [t-SNE] Computed conditional probabilities for sample 27000 / 80807
# [t-SNE] Computed conditional probabilities for sample 28000 / 80807
# [t-SNE] Computed conditional probabilities for sample 29000 / 80807
# [t-SNE] Computed conditional probabilities for sample 30000 / 80807
# [t-SNE] Computed conditional probabilities for sample 31000 / 80807
# [t-SNE] Computed conditional probabilities for sample 32000 / 80807
# [t-SNE] Computed conditional probabilities for sample 33000 / 80807
# [t-SNE] Computed conditional probabilities for sample 34000 / 80807
# [t-SNE] Computed conditional probabilities for sample 35000 / 80807
# [t-SNE] Computed conditional probabilities for sample 36000 / 80807
# [t-SNE] Computed conditional probabilities for sample 37000 / 80807
# [t-SNE] Computed conditional probabilities for sample 38000 / 80807
# [t-SNE] Computed conditional probabilities for sample 39000 / 80807
# [t-SNE] Computed conditional probabilities for sample 40000 / 80807
# [t-SNE] Computed conditional probabilities for sample 41000 / 80807
# [t-SNE] Computed conditional probabilities for sample 42000 / 80807
# [t-SNE] Computed conditional probabilities for sample 43000 / 80807
# [t-SNE] Computed conditional probabilities for sample 44000 / 80807
# [t-SNE] Computed conditional probabilities for sample 45000 / 80807
# [t-SNE] Computed conditional probabilities for sample 46000 / 80807
# [t-SNE] Computed conditional probabilities for sample 47000 / 80807
# [t-SNE] Computed conditional probabilities for sample 48000 / 80807
# [t-SNE] Computed conditional probabilities for sample 49000 / 80807
# [t-SNE] Computed conditional probabilities for sample 50000 / 80807
# [t-SNE] Computed conditional probabilities for sample 51000 / 80807
# [t-SNE] Computed conditional probabilities for sample 52000 / 80807
# [t-SNE] Computed conditional probabilities for sample 53000 / 80807
# [t-SNE] Computed conditional probabilities for sample 54000 / 80807
# [t-SNE] Computed conditional probabilities for sample 55000 / 80807
# [t-SNE] Computed conditional probabilities for sample 56000 / 80807
# [t-SNE] Computed conditional probabilities for sample 57000 / 80807
# [t-SNE] Computed conditional probabilities for sample 58000 / 80807
# [t-SNE] Computed conditional probabilities for sample 59000 / 80807
# [t-SNE] Computed conditional probabilities for sample 60000 / 80807
# [t-SNE] Computed conditional probabilities for sample 61000 / 80807
# [t-SNE] Computed conditional probabilities for sample 62000 / 80807
# [t-SNE] Computed conditional probabilities for sample 63000 / 80807
# [t-SNE] Computed conditional probabilities for sample 64000 / 80807
# [t-SNE] Computed conditional probabilities for sample 65000 / 80807
# [t-SNE] Computed conditional probabilities for sample 66000 / 80807
# [t-SNE] Computed conditional probabilities for sample 67000 / 80807
# [t-SNE] Computed conditional probabilities for sample 68000 / 80807
# [t-SNE] Computed conditional probabilities for sample 69000 / 80807
# [t-SNE] Computed conditional probabilities for sample 70000 / 80807
# [t-SNE] Computed conditional probabilities for sample 71000 / 80807
# [t-SNE] Computed conditional probabilities for sample 72000 / 80807
# [t-SNE] Computed conditional probabilities for sample 73000 / 80807
# [t-SNE] Computed conditional probabilities for sample 74000 / 80807
# [t-SNE] Computed conditional probabilities for sample 75000 / 80807
# [t-SNE] Computed conditional probabilities for sample 76000 / 80807
# [t-SNE] Computed conditional probabilities for sample 77000 / 80807
# [t-SNE] Computed conditional probabilities for sample 78000 / 80807
# [t-SNE] Computed conditional probabilities for sample 79000 / 80807
# [t-SNE] Computed conditional probabilities for sample 80000 / 80807
# [t-SNE] Computed conditional probabilities for sample 80807 / 80807
# [t-SNE] Mean sigma: 0.674097
# [t-SNE] Computed conditional probabilities in 2.919s
# [t-SNE] Iteration 50: error = 104.4070129, gradient norm = 0.0089810 (50 iterations in 79.538s)
# [t-SNE] Iteration 100: error = 92.1081772, gradient norm = 0.0028376 (50 iterations in 44.246s)
# [t-SNE] Iteration 150: error = 88.5786591, gradient norm = 0.0016982 (50 iterations in 42.815s)
# [t-SNE] Iteration 200: error = 86.7253418, gradient norm = 0.0012199 (50 iterations in 42.289s)
# [t-SNE] Iteration 250: error = 85.5776443, gradient norm = 0.0009387 (50 iterations in 40.223s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.577644
# [t-SNE] Iteration 300: error = 3.6520884, gradient norm = 0.0023795 (50 iterations in 46.140s)
# [t-SNE] Iteration 350: error = 2.9690378, gradient norm = 0.0022985 (50 iterations in 50.918s)
# [t-SNE] Iteration 400: error = 2.5547581, gradient norm = 0.0019888 (50 iterations in 46.944s)
# [t-SNE] Iteration 450: error = 2.2937756, gradient norm = 0.0017248 (50 iterations in 54.583s)
# [t-SNE] Iteration 500: error = 2.1152873, gradient norm = 0.0015260 (50 iterations in 47.664s)
# [t-SNE] Iteration 550: error = 1.9859830, gradient norm = 0.0013689 (50 iterations in 49.429s)
# [t-SNE] Iteration 600: error = 1.8880352, gradient norm = 0.0012485 (50 iterations in 54.800s)
# [t-SNE] Iteration 650: error = 1.8120981, gradient norm = 0.0011169 (50 iterations in 51.753s)
# [t-SNE] Iteration 700: error = 1.7535995, gradient norm = 0.0009939 (50 iterations in 46.750s)
# [t-SNE] Iteration 750: error = 1.7092154, gradient norm = 0.0008328 (50 iterations in 50.743s)
# [t-SNE] Iteration 800: error = 1.6754216, gradient norm = 0.0007087 (50 iterations in 49.062s)
# [t-SNE] Iteration 850: error = 1.6505238, gradient norm = 0.0005592 (50 iterations in 47.865s)
# [t-SNE] Iteration 900: error = 1.6314992, gradient norm = 0.0004875 (50 iterations in 48.385s)
# [t-SNE] Iteration 950: error = 1.6171634, gradient norm = 0.0003863 (50 iterations in 54.357s)
# [t-SNE] Iteration 1000: error = 1.6062025, gradient norm = 0.0003176 (50 iterations in 54.122s)
# [t-SNE] KL divergence after 1000 iterations: 1.606202
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 92901 samples in 0.003s...
# [t-SNE] Computed neighbors for 92901 samples in 13.367s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 92901
# [t-SNE] Computed conditional probabilities for sample 2000 / 92901
# [t-SNE] Computed conditional probabilities for sample 3000 / 92901
# [t-SNE] Computed conditional probabilities for sample 4000 / 92901
# [t-SNE] Computed conditional probabilities for sample 5000 / 92901
# [t-SNE] Computed conditional probabilities for sample 6000 / 92901
# [t-SNE] Computed conditional probabilities for sample 7000 / 92901
# [t-SNE] Computed conditional probabilities for sample 8000 / 92901
# [t-SNE] Computed conditional probabilities for sample 9000 / 92901
# [t-SNE] Computed conditional probabilities for sample 10000 / 92901
# [t-SNE] Computed conditional probabilities for sample 11000 / 92901
# [t-SNE] Computed conditional probabilities for sample 12000 / 92901
# [t-SNE] Computed conditional probabilities for sample 13000 / 92901
# [t-SNE] Computed conditional probabilities for sample 14000 / 92901
# [t-SNE] Computed conditional probabilities for sample 15000 / 92901
# [t-SNE] Computed conditional probabilities for sample 16000 / 92901
# [t-SNE] Computed conditional probabilities for sample 17000 / 92901
# [t-SNE] Computed conditional probabilities for sample 18000 / 92901
# [t-SNE] Computed conditional probabilities for sample 19000 / 92901
# [t-SNE] Computed conditional probabilities for sample 20000 / 92901
# [t-SNE] Computed conditional probabilities for sample 21000 / 92901
# [t-SNE] Computed conditional probabilities for sample 22000 / 92901
# [t-SNE] Computed conditional probabilities for sample 23000 / 92901
# [t-SNE] Computed conditional probabilities for sample 24000 / 92901
# [t-SNE] Computed conditional probabilities for sample 25000 / 92901
# [t-SNE] Computed conditional probabilities for sample 26000 / 92901
# [t-SNE] Computed conditional probabilities for sample 27000 / 92901
# [t-SNE] Computed conditional probabilities for sample 28000 / 92901
# [t-SNE] Computed conditional probabilities for sample 29000 / 92901
# [t-SNE] Computed conditional probabilities for sample 30000 / 92901
# [t-SNE] Computed conditional probabilities for sample 31000 / 92901
# [t-SNE] Computed conditional probabilities for sample 32000 / 92901
# [t-SNE] Computed conditional probabilities for sample 33000 / 92901
# [t-SNE] Computed conditional probabilities for sample 34000 / 92901
# [t-SNE] Computed conditional probabilities for sample 35000 / 92901
# [t-SNE] Computed conditional probabilities for sample 36000 / 92901
# [t-SNE] Computed conditional probabilities for sample 37000 / 92901
# [t-SNE] Computed conditional probabilities for sample 38000 / 92901
# [t-SNE] Computed conditional probabilities for sample 39000 / 92901
# [t-SNE] Computed conditional probabilities for sample 40000 / 92901
# [t-SNE] Computed conditional probabilities for sample 41000 / 92901
# [t-SNE] Computed conditional probabilities for sample 42000 / 92901
# [t-SNE] Computed conditional probabilities for sample 43000 / 92901
# [t-SNE] Computed conditional probabilities for sample 44000 / 92901
# [t-SNE] Computed conditional probabilities for sample 45000 / 92901
# [t-SNE] Computed conditional probabilities for sample 46000 / 92901
# [t-SNE] Computed conditional probabilities for sample 47000 / 92901
# [t-SNE] Computed conditional probabilities for sample 48000 / 92901
# [t-SNE] Computed conditional probabilities for sample 49000 / 92901
# [t-SNE] Computed conditional probabilities for sample 50000 / 92901
# [t-SNE] Computed conditional probabilities for sample 51000 / 92901
# [t-SNE] Computed conditional probabilities for sample 52000 / 92901
# [t-SNE] Computed conditional probabilities for sample 53000 / 92901
# [t-SNE] Computed conditional probabilities for sample 54000 / 92901
# [t-SNE] Computed conditional probabilities for sample 55000 / 92901
# [t-SNE] Computed conditional probabilities for sample 56000 / 92901
# [t-SNE] Computed conditional probabilities for sample 57000 / 92901
# [t-SNE] Computed conditional probabilities for sample 58000 / 92901
# [t-SNE] Computed conditional probabilities for sample 59000 / 92901
# [t-SNE] Computed conditional probabilities for sample 60000 / 92901
# [t-SNE] Computed conditional probabilities for sample 61000 / 92901
# [t-SNE] Computed conditional probabilities for sample 62000 / 92901
# [t-SNE] Computed conditional probabilities for sample 63000 / 92901
# [t-SNE] Computed conditional probabilities for sample 64000 / 92901
# [t-SNE] Computed conditional probabilities for sample 65000 / 92901
# [t-SNE] Computed conditional probabilities for sample 66000 / 92901
# [t-SNE] Computed conditional probabilities for sample 67000 / 92901
# [t-SNE] Computed conditional probabilities for sample 68000 / 92901
# [t-SNE] Computed conditional probabilities for sample 69000 / 92901
# [t-SNE] Computed conditional probabilities for sample 70000 / 92901
# [t-SNE] Computed conditional probabilities for sample 71000 / 92901
# [t-SNE] Computed conditional probabilities for sample 72000 / 92901
# [t-SNE] Computed conditional probabilities for sample 73000 / 92901
# [t-SNE] Computed conditional probabilities for sample 74000 / 92901
# [t-SNE] Computed conditional probabilities for sample 75000 / 92901
# [t-SNE] Computed conditional probabilities for sample 76000 / 92901
# [t-SNE] Computed conditional probabilities for sample 77000 / 92901
# [t-SNE] Computed conditional probabilities for sample 78000 / 92901
# [t-SNE] Computed conditional probabilities for sample 79000 / 92901
# [t-SNE] Computed conditional probabilities for sample 80000 / 92901
# [t-SNE] Computed conditional probabilities for sample 81000 / 92901
# [t-SNE] Computed conditional probabilities for sample 82000 / 92901
# [t-SNE] Computed conditional probabilities for sample 83000 / 92901
# [t-SNE] Computed conditional probabilities for sample 84000 / 92901
# [t-SNE] Computed conditional probabilities for sample 85000 / 92901
# [t-SNE] Computed conditional probabilities for sample 86000 / 92901
# [t-SNE] Computed conditional probabilities for sample 87000 / 92901
# [t-SNE] Computed conditional probabilities for sample 88000 / 92901
# [t-SNE] Computed conditional probabilities for sample 89000 / 92901
# [t-SNE] Computed conditional probabilities for sample 90000 / 92901
# [t-SNE] Computed conditional probabilities for sample 91000 / 92901
# [t-SNE] Computed conditional probabilities for sample 92000 / 92901
# [t-SNE] Computed conditional probabilities for sample 92901 / 92901
# [t-SNE] Mean sigma: 0.658226
# [t-SNE] Computed conditional probabilities in 3.426s
# [t-SNE] Iteration 50: error = 105.8870010, gradient norm = 0.0083462 (50 iterations in 93.451s)
# [t-SNE] Iteration 100: error = 93.3176346, gradient norm = 0.0026965 (50 iterations in 61.904s)
# [t-SNE] Iteration 150: error = 89.5940247, gradient norm = 0.0016259 (50 iterations in 59.139s)
# [t-SNE] Iteration 200: error = 87.6467514, gradient norm = 0.0011615 (50 iterations in 50.634s)
# [t-SNE] Iteration 250: error = 86.4361420, gradient norm = 0.0009006 (50 iterations in 48.936s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 86.436142
# [t-SNE] Iteration 300: error = 3.7473559, gradient norm = 0.0022590 (50 iterations in 57.010s)
# [t-SNE] Iteration 350: error = 3.0459647, gradient norm = 0.0021872 (50 iterations in 62.211s)
# [t-SNE] Iteration 400: error = 2.6227083, gradient norm = 0.0018835 (50 iterations in 66.239s)
# [t-SNE] Iteration 450: error = 2.3549948, gradient norm = 0.0016406 (50 iterations in 55.377s)
# [t-SNE] Iteration 500: error = 2.1711600, gradient norm = 0.0014494 (50 iterations in 59.392s)
# [t-SNE] Iteration 550: error = 2.0375059, gradient norm = 0.0013007 (50 iterations in 61.243s)
# [t-SNE] Iteration 600: error = 1.9361891, gradient norm = 0.0011809 (50 iterations in 67.420s)
# [t-SNE] Iteration 650: error = 1.8578428, gradient norm = 0.0010610 (50 iterations in 58.746s)
# [t-SNE] Iteration 700: error = 1.7964783, gradient norm = 0.0009497 (50 iterations in 58.891s)
# [t-SNE] Iteration 750: error = 1.7485857, gradient norm = 0.0008240 (50 iterations in 56.138s)
# [t-SNE] Iteration 800: error = 1.7113954, gradient norm = 0.0007015 (50 iterations in 56.039s)
# [t-SNE] Iteration 850: error = 1.6824628, gradient norm = 0.0006025 (50 iterations in 55.744s)
# [t-SNE] Iteration 900: error = 1.6595625, gradient norm = 0.0005187 (50 iterations in 59.582s)
# [t-SNE] Iteration 950: error = 1.6414748, gradient norm = 0.0004361 (50 iterations in 60.833s)
# [t-SNE] Iteration 1000: error = 1.6273434, gradient norm = 0.0003648 (50 iterations in 63.898s)
# [t-SNE] KL divergence after 1000 iterations: 1.627343
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 92901 samples in 0.004s...
# [t-SNE] Computed neighbors for 92901 samples in 13.782s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 92901
# [t-SNE] Computed conditional probabilities for sample 2000 / 92901
# [t-SNE] Computed conditional probabilities for sample 3000 / 92901
# [t-SNE] Computed conditional probabilities for sample 4000 / 92901
# [t-SNE] Computed conditional probabilities for sample 5000 / 92901
# [t-SNE] Computed conditional probabilities for sample 6000 / 92901
# [t-SNE] Computed conditional probabilities for sample 7000 / 92901
# [t-SNE] Computed conditional probabilities for sample 8000 / 92901
# [t-SNE] Computed conditional probabilities for sample 9000 / 92901
# [t-SNE] Computed conditional probabilities for sample 10000 / 92901
# [t-SNE] Computed conditional probabilities for sample 11000 / 92901
# [t-SNE] Computed conditional probabilities for sample 12000 / 92901
# [t-SNE] Computed conditional probabilities for sample 13000 / 92901
# [t-SNE] Computed conditional probabilities for sample 14000 / 92901
# [t-SNE] Computed conditional probabilities for sample 15000 / 92901
# [t-SNE] Computed conditional probabilities for sample 16000 / 92901
# [t-SNE] Computed conditional probabilities for sample 17000 / 92901
# [t-SNE] Computed conditional probabilities for sample 18000 / 92901
# [t-SNE] Computed conditional probabilities for sample 19000 / 92901
# [t-SNE] Computed conditional probabilities for sample 20000 / 92901
# [t-SNE] Computed conditional probabilities for sample 21000 / 92901
# [t-SNE] Computed conditional probabilities for sample 22000 / 92901
# [t-SNE] Computed conditional probabilities for sample 23000 / 92901
# [t-SNE] Computed conditional probabilities for sample 24000 / 92901
# [t-SNE] Computed conditional probabilities for sample 25000 / 92901
# [t-SNE] Computed conditional probabilities for sample 26000 / 92901
# [t-SNE] Computed conditional probabilities for sample 27000 / 92901
# [t-SNE] Computed conditional probabilities for sample 28000 / 92901
# [t-SNE] Computed conditional probabilities for sample 29000 / 92901
# [t-SNE] Computed conditional probabilities for sample 30000 / 92901
# [t-SNE] Computed conditional probabilities for sample 31000 / 92901
# [t-SNE] Computed conditional probabilities for sample 32000 / 92901
# [t-SNE] Computed conditional probabilities for sample 33000 / 92901
# [t-SNE] Computed conditional probabilities for sample 34000 / 92901
# [t-SNE] Computed conditional probabilities for sample 35000 / 92901
# [t-SNE] Computed conditional probabilities for sample 36000 / 92901
# [t-SNE] Computed conditional probabilities for sample 37000 / 92901
# [t-SNE] Computed conditional probabilities for sample 38000 / 92901
# [t-SNE] Computed conditional probabilities for sample 39000 / 92901
# [t-SNE] Computed conditional probabilities for sample 40000 / 92901
# [t-SNE] Computed conditional probabilities for sample 41000 / 92901
# [t-SNE] Computed conditional probabilities for sample 42000 / 92901
# [t-SNE] Computed conditional probabilities for sample 43000 / 92901
# [t-SNE] Computed conditional probabilities for sample 44000 / 92901
# [t-SNE] Computed conditional probabilities for sample 45000 / 92901
# [t-SNE] Computed conditional probabilities for sample 46000 / 92901
# [t-SNE] Computed conditional probabilities for sample 47000 / 92901
# [t-SNE] Computed conditional probabilities for sample 48000 / 92901
# [t-SNE] Computed conditional probabilities for sample 49000 / 92901
# [t-SNE] Computed conditional probabilities for sample 50000 / 92901
# [t-SNE] Computed conditional probabilities for sample 51000 / 92901
# [t-SNE] Computed conditional probabilities for sample 52000 / 92901
# [t-SNE] Computed conditional probabilities for sample 53000 / 92901
# [t-SNE] Computed conditional probabilities for sample 54000 / 92901
# [t-SNE] Computed conditional probabilities for sample 55000 / 92901
# [t-SNE] Computed conditional probabilities for sample 56000 / 92901
# [t-SNE] Computed conditional probabilities for sample 57000 / 92901
# [t-SNE] Computed conditional probabilities for sample 58000 / 92901
# [t-SNE] Computed conditional probabilities for sample 59000 / 92901
# [t-SNE] Computed conditional probabilities for sample 60000 / 92901
# [t-SNE] Computed conditional probabilities for sample 61000 / 92901
# [t-SNE] Computed conditional probabilities for sample 62000 / 92901
# [t-SNE] Computed conditional probabilities for sample 63000 / 92901
# [t-SNE] Computed conditional probabilities for sample 64000 / 92901
# [t-SNE] Computed conditional probabilities for sample 65000 / 92901
# [t-SNE] Computed conditional probabilities for sample 66000 / 92901
# [t-SNE] Computed conditional probabilities for sample 67000 / 92901
# [t-SNE] Computed conditional probabilities for sample 68000 / 92901
# [t-SNE] Computed conditional probabilities for sample 69000 / 92901
# [t-SNE] Computed conditional probabilities for sample 70000 / 92901
# [t-SNE] Computed conditional probabilities for sample 71000 / 92901
# [t-SNE] Computed conditional probabilities for sample 72000 / 92901
# [t-SNE] Computed conditional probabilities for sample 73000 / 92901
# [t-SNE] Computed conditional probabilities for sample 74000 / 92901
# [t-SNE] Computed conditional probabilities for sample 75000 / 92901
# [t-SNE] Computed conditional probabilities for sample 76000 / 92901
# [t-SNE] Computed conditional probabilities for sample 77000 / 92901
# [t-SNE] Computed conditional probabilities for sample 78000 / 92901
# [t-SNE] Computed conditional probabilities for sample 79000 / 92901
# [t-SNE] Computed conditional probabilities for sample 80000 / 92901
# [t-SNE] Computed conditional probabilities for sample 81000 / 92901
# [t-SNE] Computed conditional probabilities for sample 82000 / 92901
# [t-SNE] Computed conditional probabilities for sample 83000 / 92901
# [t-SNE] Computed conditional probabilities for sample 84000 / 92901
# [t-SNE] Computed conditional probabilities for sample 85000 / 92901
# [t-SNE] Computed conditional probabilities for sample 86000 / 92901
# [t-SNE] Computed conditional probabilities for sample 87000 / 92901
# [t-SNE] Computed conditional probabilities for sample 88000 / 92901
# [t-SNE] Computed conditional probabilities for sample 89000 / 92901
# [t-SNE] Computed conditional probabilities for sample 90000 / 92901
# [t-SNE] Computed conditional probabilities for sample 91000 / 92901
# [t-SNE] Computed conditional probabilities for sample 92000 / 92901
# [t-SNE] Computed conditional probabilities for sample 92901 / 92901
# [t-SNE] Mean sigma: 0.658226
# [t-SNE] Computed conditional probabilities in 3.062s
# [t-SNE] Iteration 50: error = 105.8869934, gradient norm = 0.0083462 (50 iterations in 93.825s)
# [t-SNE] Iteration 100: error = 93.3176346, gradient norm = 0.0026965 (50 iterations in 61.403s)
# [t-SNE] Iteration 150: error = 89.5940170, gradient norm = 0.0016259 (50 iterations in 52.784s)
# [t-SNE] Iteration 200: error = 87.6467438, gradient norm = 0.0011615 (50 iterations in 46.141s)
# [t-SNE] Iteration 250: error = 86.4361420, gradient norm = 0.0009006 (50 iterations in 47.459s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 86.436142
# [t-SNE] Iteration 300: error = 3.7473557, gradient norm = 0.0022590 (50 iterations in 60.329s)
# [t-SNE] Iteration 350: error = 3.0459647, gradient norm = 0.0021872 (50 iterations in 65.714s)
# [t-SNE] Iteration 400: error = 2.6227083, gradient norm = 0.0018835 (50 iterations in 71.955s)
# [t-SNE] Iteration 450: error = 2.3549948, gradient norm = 0.0016406 (50 iterations in 58.022s)
# [t-SNE] Iteration 500: error = 2.1711602, gradient norm = 0.0014494 (50 iterations in 53.446s)
# [t-SNE] Iteration 550: error = 2.0375056, gradient norm = 0.0013007 (50 iterations in 53.229s)
# [t-SNE] Iteration 600: error = 1.9361891, gradient norm = 0.0011809 (50 iterations in 53.538s)
# [t-SNE] Iteration 650: error = 1.8578427, gradient norm = 0.0010610 (50 iterations in 52.754s)
# [t-SNE] Iteration 700: error = 1.7964782, gradient norm = 0.0009497 (50 iterations in 52.752s)
# [t-SNE] Iteration 750: error = 1.7485859, gradient norm = 0.0008240 (50 iterations in 52.201s)
# [t-SNE] Iteration 800: error = 1.7113954, gradient norm = 0.0007015 (50 iterations in 50.474s)
# [t-SNE] Iteration 850: error = 1.6824627, gradient norm = 0.0006025 (50 iterations in 53.226s)
# [t-SNE] Iteration 900: error = 1.6595623, gradient norm = 0.0005187 (50 iterations in 55.294s)
# [t-SNE] Iteration 950: error = 1.6414747, gradient norm = 0.0004361 (50 iterations in 55.396s)
# [t-SNE] Iteration 1000: error = 1.6273434, gradient norm = 0.0003648 (50 iterations in 55.741s)
# [t-SNE] KL divergence after 1000 iterations: 1.627343
